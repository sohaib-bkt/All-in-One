# %% [markdown]
# ## Data cleaning and preparation
# - Handling Missing Data
# - Correcting Data Types
# - Removing Duplicates
# - Outlier Detection and Treatment
# - Standardization and Normalization
# - Encoding Categorical Variables
# - Feature Engineering

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"data/Customer Call List.xlsx")  
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# 18        1019      Creed       Braton           N/a
# 19        1020     Anakin    Skywalker  876|678|3469
# 20        1020     Anakin    Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N
# 20            910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 0                True
# 1               False
# 2                True
# 3                True
# 4                True
# 5                True
# 6               False
# 7               False
# 8               False
# 9                True
# 10               True
# 11               True
# 12              False
# 13              False
# 14              False
# 15              False
# 16              False
# 17               True
# 18               True
# 19               True
# 20               True

# %%
df = df.drop_duplicates()

# %%
# inplace = True updates the original dataframe
df.drop(columns=["Not_Useful_Column"] , inplace=True) 
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\4264070319.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Not_Useful_Column"] , inplace=True)
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# 18        1019      Creed       Braton           N/a
# 19        1020     Anakin    Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N

# %%
df['Last_Name'] = df['Last_Name'].str.strip()
df['First_Name'] = df['First_Name'].str.strip()
df['Last_Name'] = df['Last_Name'].str.strip('123._/')
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\2757176966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Last_Name'] = df['Last_Name'].str.strip()
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\2757176966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['First_Name'] = df['First_Name'].str.strip()
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\2757176966.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Last_Name'] = df['Last_Name'].str.strip('123._/')
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123/643/9775
# 17        1018      Clark        Kent    7066950392
# 18        1019      Creed      Braton           N/a
# 19        1020     Anakin   Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N

# %%
# some of the numbers are strings and some are integers. When you run the string method during the formatting,
#  it replaces the numeric values with NaN and they are later removed completely.
df["Phone_Number"] = df["Phone_Number"].astype(str)
df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]','',regex=True)
# Use .map() when working with a Series and you need simple transformations or mappings.
# Use .apply() for complex operations or when working with a DataFrame.
df ['Phone_Number'] = df['Phone_Number'].map(lambda x: str(x)[0:3] + '-' + str(x)[3:6] + '-' + str(x)[6:10])
# df['Phone_Number'].dropna(axis=0)
df["Phone_Number"] = df["Phone_Number"].str.replace('nan--','')
df["Phone_Number"] = df["Phone_Number"].str.replace('Na--','')
# Performance: The .str.replace() method tends to be faster than apply() for large datasets, 
# so it's generally the preferred method for string manipulations in pandas.
# def fill_scores(score):  
#     if score == 'nan--':  
        
#         return ''
#     if score == 'Na--':  
        
#         return ''
#     return score  

# df['Phone_Number'].apply(fill_scores)  
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\4266252939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].astype(str)
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\4266252939.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]','',regex=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\4266252939.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df ['Phone_Number'] = df['Phone_Number'].map(lambda x: str(x)[0:3] + '-' + str(x)[3:6] + '-' + str(x)[6:10])
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\4266252939.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].str.replace('nan--','')
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\4266252939.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].str.replace('Na--','')
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N

# %%
df[['Address', 'State', 'Postal Code']] = df['Address'].str.split(',', n=2, expand=True)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\1235300189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Address', 'State', 'Postal Code']] = df['Address'].str.split(',', n=2, expand=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\1235300189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Address', 'State', 'Postal Code']] = df['Address'].str.split(',', n=2, expand=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\1235300189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Address', 'State', 'Postal Code']] = df['Address'].str.split(',', n=2, expand=True)
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White  706-695-0392    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN                    123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee                      612 Shire Lane
# 11        1012      Harry      Potter  706-695-0392  2394 Hogwarts Avenue
# 12        1013        Don      Draper  123-543-2345      2039 Main Street
# 13        1014     Leslie       Knope  876-678-3469      343 City Parkway
# 14        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 15        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
# 16        1017    Michael       Scott  123-643-9775      121 Paper Avenue
# 17        1018      Clark        Kent  706-695-0392       3498 Super Lane
# 18        1019      Creed      Braton                                 N/a
# 19        1020     Anakin   Skywalker  876-678-3469     910 Tatooine Road
#
#    Paying Customer Do_Not_Contact          State Postal Code
# 0              Yes             No          Shire        None
# 1               No            Yes           None        None
# 2                N            NaN           None        None
# 3              Yes              Y   Pennsylvania       18503
# 4                Y             No           None        None
# 5              Yes            Yes           None        None
# 6               No             No           None        None
# 7                N             No           None        None
# 8              Yes            NaN           None        None
# 9              Yes             No       New York        None
# 10             Yes             No          Shire        None
# 11               Y            NaN           None        None
# 12             Yes              N           None        None
# 13             Yes             No           None        None
# 14               N             No           None        None
# 15              No              N           None        None
# 16             Yes             No   Pennsylvania        None
# 17               Y            NaN           None        None
# 18             N/a            Yes           None        None
# 19             Yes              N       Tatooine        None

# %%
df.loc[: ,'Paying Customer'] = df['Paying Customer'].str.replace('Yes', 'Y')
df.loc[: ,'Paying Customer'] = df['Paying Customer'].str.replace('No', 'N')

# loc : This way, you ensure that you are modifying the DataFrame directly without creating a potentially ambiguous copy.
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White  706-695-0392    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN                    123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee                      612 Shire Lane
# 11        1012      Harry      Potter  706-695-0392  2394 Hogwarts Avenue
# 12        1013        Don      Draper  123-543-2345      2039 Main Street
# 13        1014     Leslie       Knope  876-678-3469      343 City Parkway
# 14        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 15        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
# 16        1017    Michael       Scott  123-643-9775      121 Paper Avenue
# 17        1018      Clark        Kent  706-695-0392       3498 Super Lane
# 18        1019      Creed      Braton                                 N/a
# 19        1020     Anakin   Skywalker  876-678-3469     910 Tatooine Road
#
#    Paying Customer Do_Not_Contact          State Postal Code
# 0                Y             No          Shire        None
# 1                N            Yes           None        None
# 2                N            NaN           None        None
# 3                Y              Y   Pennsylvania       18503
# 4                Y             No           None        None
# 5                Y            Yes           None        None
# 6                N             No           None        None
# 7                N             No           None        None
# 8                Y            NaN           None        None
# 9                Y             No       New York        None
# 10               Y             No          Shire        None
# 11               Y            NaN           None        None
# 12               Y              N           None        None
# 13               Y             No           None        None
# 14               N             No           None        None
# 15               N              N           None        None
# 16               Y             No   Pennsylvania        None
# 17               Y            NaN           None        None
# 18             N/a            Yes           None        None
# 19               Y              N       Tatooine        None

# %%
df.loc[: ,'Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('Yes', 'Y')
df.loc[: ,'Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('No', 'N')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White  706-695-0392    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf         NaN                    123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee                      612 Shire Lane
# 11        1012      Harry      Potter  706-695-0392  2394 Hogwarts Avenue
# 12        1013        Don      Draper  123-543-2345      2039 Main Street
# 13        1014     Leslie       Knope  876-678-3469      343 City Parkway
# 14        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 15        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
# 16        1017    Michael       Scott  123-643-9775      121 Paper Avenue
# 17        1018      Clark        Kent  706-695-0392       3498 Super Lane
# 18        1019      Creed      Braton                                 N/a
# 19        1020     Anakin   Skywalker  876-678-3469     910 Tatooine Road
#
#    Paying Customer Do_Not_Contact          State Postal Code
# 0                Y              N          Shire        None
# 1                N              Y           None        None
# 2                N            NaN           None        None
# 3                Y              Y   Pennsylvania       18503
# 4                Y              N           None        None
# 5                Y              Y           None        None
# 6                N              N           None        None
# 7                N              N           None        None
# 8                Y            NaN           None        None
# 9                Y              N       New York        None
# 10               Y              N          Shire        None
# 11               Y            NaN           None        None
# 12               Y              N           None        None
# 13               Y              N           None        None
# 14               N              N           None        None
# 15               N              N           None        None
# 16               Y              N   Pennsylvania        None
# 17               Y            NaN           None        None
# 18             N/a              Y           None        None
# 19               Y              N       Tatooine        None

# %%
df['Phone_Number'] = df['Phone_Number'].replace('--', np.nan )
df = df.replace('N/a' , '')
df = df.replace('NaN' , '')
df = df.fillna('')

df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23520\3618368104.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number'] = df['Phone_Number'].replace('--', np.nan )
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White  706-695-0392    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 8         1009    Gandalf                                123 Middle Earth
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 10        1011    Samwise      Gamgee                      612 Shire Lane
# 11        1012      Harry      Potter  706-695-0392  2394 Hogwarts Avenue
# 12        1013        Don      Draper  123-543-2345      2039 Main Street
# 13        1014     Leslie       Knope  876-678-3469      343 City Parkway
# 14        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 15        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
# 16        1017    Michael       Scott  123-643-9775      121 Paper Avenue
# 17        1018      Clark        Kent  706-695-0392       3498 Super Lane
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469     910 Tatooine Road
#
#    Paying Customer Do_Not_Contact          State Postal Code
# 0                Y              N          Shire
# 1                N              Y
# 2                N
# 3                Y              Y   Pennsylvania       18503
# 4                Y              N
# 5                Y              Y
# 6                N              N
# 7                N              N
# 8                Y
# 9                Y              N       New York
# 10               Y              N          Shire
# 11               Y
# 12               Y              N
# 13               Y              N
# 14               N              N
# 15               N              N
# 16               Y              N   Pennsylvania
# 17               Y
# 18                              Y
# 19               Y              N       Tatooine

# %%
#df.loc[row_indexer, column_indexer] = value  

# .loc: Label-based indexing (uses row and column labels).
# .iloc: Integer-based indexing (uses row and column positions).

# Select rows 'a' to 'b' (inclusive) for all columns
# range_rows = df.loc["a":"b"]

# Select rows where Age > 25
# age_filter = df.loc[df["Age"] > 25]

# Add a new column
# df.loc[:, "Country"] = ["USA", "USA", "USA"]


for x in df.index:
    if df.loc[x, "Phone_Number"] == '':
        df.drop(x, inplace=True)

df

# another way
# df['Phone_Number' ].replace('', np.nan , inplace=True)
# df = df.dropna(subset=["Phone_Number"])  

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White  706-695-0392    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 7         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 9         1010      Peter      Parker  123-545-5421      25th Main Street
# 11        1012      Harry      Potter  706-695-0392  2394 Hogwarts Avenue
# 12        1013        Don      Draper  123-543-2345      2039 Main Street
# 13        1014     Leslie       Knope  876-678-3469      343 City Parkway
# 14        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 15        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
# 16        1017    Michael       Scott  123-643-9775      121 Paper Avenue
# 17        1018      Clark        Kent  706-695-0392       3498 Super Lane
# 19        1020     Anakin   Skywalker  876-678-3469     910 Tatooine Road
#
#    Paying Customer Do_Not_Contact          State Postal Code
# 0                Y              N          Shire
# 1                N              Y
# 2                N
# 3                Y              Y   Pennsylvania       18503
# 4                Y              N
# 5                Y              Y
# 7                N              N
# 9                Y              N       New York
# 11               Y
# 12               Y              N
# 13               Y              N
# 14               N              N
# 15               N              N
# 16               Y              N   Pennsylvania
# 17               Y
# 19               Y              N       Tatooine

# %%
df.reset_index(drop=True, inplace=True) 
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0         1001      Frodo     Baggins  123-545-5421        123 Shire Lane
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 2         1003     Walter       White  706-695-0392    298 Drugs Driveway
# 3         1004     Dwight     Schrute  123-543-2345      980 Paper Avenue
# 4         1005        Jon        Snow  876-678-3469      123 Dragons Road
# 5         1006        Ron     Swanson  304-762-2467      768 City Parkway
# 6         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 7         1010      Peter      Parker  123-545-5421      25th Main Street
# 8         1012      Harry      Potter  706-695-0392  2394 Hogwarts Avenue
# 9         1013        Don      Draper  123-543-2345      2039 Main Street
# 10        1014     Leslie       Knope  876-678-3469      343 City Parkway
# 11        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 12        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
# 13        1017    Michael       Scott  123-643-9775      121 Paper Avenue
# 14        1018      Clark        Kent  706-695-0392       3498 Super Lane
# 15        1020     Anakin   Skywalker  876-678-3469     910 Tatooine Road
#
#    Paying Customer Do_Not_Contact          State Postal Code
# 0                Y              N          Shire
# 1                N              Y
# 2                N
# 3                Y              Y   Pennsylvania       18503
# 4                Y              N
# 5                Y              Y
# 6                N              N
# 7                Y              N       New York
# 8                Y
# 9                Y              N
# 10               Y              N
# 11               N              N
# 12               N              N
# 13               Y              N   Pennsylvania
# 14               Y
# 15               Y              N       Tatooine
